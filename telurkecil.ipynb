# %%
# mengimportkan gambar pisau nya(fungsi menampilkan gambar)
from IPython.display import Image
import numpy as np # library untuk mengolah matriksnya
import cv2 #cv2 untuk mengelola gambar
Image(filename='telur kecil kotor.jpg')

# %%
image = cv2.imread("telur kecil kotor.jpg") #mengambil gambar dijadikan bentuk array dengan format bgr
img_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
import matplotlib.pyplot as plt 
plt.imshow(img_gray, cmap='gray', vmin=0, vmax=255)
plt.show() #menampilkan gambar
for i in range(len(img_gray)): # menampilkan data pixel
    for j in range(len(img_gray[0])):
        print(str(img_gray[i][j])+",", end="")
    print()
# Out:
# 254,254,254,254,254,254,254,254,254,254,254,254,254,254,254,254,254,254,254,254,254,254,254,254,254,255,254,252,251,251,252,251,254,254,251,253,252,252,253,253,252,252,253,253,253,253,253,254,254,254,254,254,254,254,254,254,254,254,254,254,
# 254,254,254,254,254,254,254,254,254,254,254,254,254,254,254,254,254,254,254,254,254,254,254,254,253,254,255,254,254,254,254,254,252,252,254,255,254,253,250,250,253,253,253,253,253,253,254,254,254,254,254,254,254,254,254,254,254,254,254,254,
# 254,254,254,254,254,254,254,254,254,254,254,254,254,254,254,254,254,254,254,254,254,254,254,254,255,253,252,254,255,255,252,247,253,254,254,255,255,254,253,253,253,253,253,253,253,253,254,254,254,254,254,254,254,254,254,254,254,254,254,254,
# 254,254,254,254,254,254,254,254,254,254,254,254,254,254,254,254,254,254,254,254,254,254,254,254,255,253,252,254,254,252,252,253,254,254,254,250,251,254,254,254,254,254,254,254,254,254,254,254,254,254,254,254,254,254,254,254,254,254,254,254,
# ...

# %%
# for j in range(len(numpy_array[0])):
#             if numpy_array[i][j] > threshold:
#                 numpy_array[i][j] = 255
#             else:
#                 numpy_array[i][j] = 0
#     return numpy_array

for i in range(len(img_gray)): #mengubah warna menjadi hitam putih 
    for j in range(len(img_gray[0])):
        if img_gray[i][j] > 100:
            img_gray[i][j] = 255
        else:
                img_gray[i][j] = 0
#     return img_array
plt.imshow(img_gray, cmap='gray', vmin=0, vmax=255)
plt.show() #menampilkan gambar

# %%
# menghitung jumlah pixel warna hitam 
hitung=0
for i in range(len(img_gray)):
    for j in range(len(img_gray[0])):
        if img_gray[i][j] == 0:
            hitung=hitung+1
#     return img_array
if hitung > 18:
    print('telur kotor')
else:
    print('telur bersih')
# Out:
# telur kotor

# %%
# Out:
# 255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,25
# ...
